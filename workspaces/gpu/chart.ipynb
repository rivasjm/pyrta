# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("results.csv")

# %%
df
# Out:
#        Period  1 iterations  2 iterations  3 iterations  4 iterations  \
# 0    0.600000       146.000       244.000       342.000       440.000
# 1    3.726316       149.842       248.211       346.579       444.947
# 2    6.852632       151.658       255.342       359.026       462.711
# 3    9.978947       157.474       257.053       356.632       456.211
# 4   13.105263       164.289       265.974       367.658       469.342
# 5   16.231579       160.684       259.263       357.842       456.421
# 6   19.357895       162.789       269.184       375.579       481.974
# 7   22.484211       159.684       273.895       388.105       502.316
# 8   25.610526       172.711       273.395       374.079       474.763
# 9   28.736842       185.737       291.632       397.526       503.421
# 10  31.863158       172.211       283.316       394.421       505.526
# 11  34.989474       153.474       269.789       386.105       502.421
# ...

# %%
df.set_index("Period").plot()
# Out:
# <Axes: xlabel='Period'>
