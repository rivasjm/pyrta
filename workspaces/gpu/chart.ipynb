# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("results_holistic.csv")

# %%
df
# Out:
#     Period  1 iterations  2 iterations  3 iterations  4 iterations  \
# 0     1.25         70.00        117.50        175.00        262.50
# 1     2.50         70.00        117.50        175.00        262.50
# 2     3.75         71.50        121.25        177.25        265.50
# 3     5.00         73.00        122.00        181.00        270.00
# 4     6.25         73.75        125.00        184.00        270.00
# 5     7.50         76.00        123.50        179.50        270.00
# 6     8.75         71.50        122.75        188.50        276.75
# 7    10.00         76.00        125.00        184.00        273.00
# 8    11.25         80.50        132.50        188.50        305.00
# 9    12.50         77.50        132.50        203.00        300.50
# 10   13.75         81.25        131.00        197.00        308.00
# 11   15.00         85.00        137.00        193.00        305.00
# 12   16.25         88.75        143.00        215.00        322.50
# ...

# %%
df.set_index("Period").plot()
# Out:
# <Axes: xlabel='Period'>

# %%
df = pd.read_csv("results_precedence.csv")

# %%
df
# Out:
#     Period  1 iterations  2 iterations  3 iterations  4 iterations  \
# 0     1.25         45.00          65.0         85.00        105.00
# 1     2.50         45.00          65.0         85.00        105.00
# 2     3.75         45.75          66.5         87.25        125.75
# 3     5.00         48.00          68.0         88.00        108.00
# 4     6.25         52.50          74.0         95.50        125.00
# 5     7.50         48.00          71.0         94.00        138.50
# 6     8.75         51.00          75.5        100.00        166.75
# 7    10.00         48.00          68.0         88.00        108.00
# 8    11.25         50.25          71.0         91.75        141.00
# 9    12.50         52.50          74.0         95.50        140.00
# 10   13.75         54.75          77.0         99.25        137.75
# 11   15.00         57.00          80.0        103.00        169.00
# 12   16.25         59.25          83.0        106.75        166.00
# ...

# %%
df.set_index("Period").plot()
# Out:
# <Axes: xlabel='Period'>
